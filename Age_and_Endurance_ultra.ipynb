# %%
import zipfile
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#um_df = pd.read_csv("/Users/justinmasters/Documents/DA_prereq_Justin_Masters/Notebooks/Age_and_Endurance/Data/TWO_CENTURIES_OF_UM_RACES.csv")
#um_df.head()
# Out:
# /var/folders/77/qj38nbbs3bq7mscbtmmv1lzw0000gn/T/ipykernel_96678/2434592376.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   um_df = pd.read_csv("/Users/justinmasters/Documents/DA_prereq_Justin_Masters/Notebooks/Age_and_Endurance/Data/TWO_CENTURIES_OF_UM_RACES.csv")
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4

# %%
#um_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461195 entries, 0 to 7461194
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 740.0+ MB

# %%
#um_df = um_df[um_df['Year of event'] >= 2016]

# %%
#um_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3609806 entries, 0 to 3609805
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 385.6+ MB

# %%
#um_df.isnull().sum()
# Out:
# Year of event                      0
# Event dates                        0
# Event name                         0
# Event distance/length            563
# Event number of finishers          0
# Athlete performance                0
# Athlete club                 1515502
# Athlete country                    1
# Athlete year of birth         255368
# Athlete gender                     1
# Athlete age category          254048
# Athlete average speed             56
# Athlete ID                         0
# dtype: int64

# %%
#um_df[um_df.isnull().any(axis=1)]
# Out:
#          Year of event Event dates                          Event name  \
# 5                 2018  06.01.2018                 Selva Costera (CHI)
# 11                2018  06.01.2018                 Selva Costera (CHI)
# 16                2018  06.01.2018                 Selva Costera (CHI)
# 19                2018  06.01.2018                 Selva Costera (CHI)
# 20                2018  06.01.2018                 Selva Costera (CHI)
# ...                ...         ...                                 ...
# 3609767           2022  16.10.2022         Crater Rim Ultra 83km (NZL)
# 3609768           2022  16.10.2022         Crater Rim Ultra 83km (NZL)
# 3609769           2022  16.10.2022         Crater Rim Ultra 83km (NZL)
# 3609770           2022  16.10.2022         Crater Rim Ultra 83km (NZL)
# 3609771           2022  16.10.2022  Tussey Mountainback 50 Miler (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 5                        50km                         22           6:25:01 h
# 11                       50km                         22           7:09:58 h
# 16                       50km                         22           8:00:56 h
# 19                       50km                         22           8:13:16 h
# 20                       50km                         22           8:13:28 h
# ...                       ...                        ...                 ...
# 3609767                  83km                         21          13:42:34 h
# 3609768                  83km                         21          13:55:09 h
# 3609769                  83km                         21          14:00:10 h
# 3609770                  83km                         21          14:11:46 h
# 3609771                  50mi                         35           7:07:38 h
#
#                       Athlete club Athlete country  Athlete year of birth  \
# 5                              NaN             ARG                 1974.0
# 11                     Rocoto Team             CHI                    NaN
# 16                             NaN             CHI                 1971.0
# 19       Santiago Mountain Runn...             CHI                    NaN
# 20                  MEF Ularunners             CHI                    NaN
# ...                            ...             ...                    ...
# 3609767                        NaN             NZL                    NaN
# 3609768                        NaN             NZL                    NaN
# 3609769                        NaN             NZL                 1994.0
# 3609770                        NaN             NZL                    NaN
# 3609771                        NaN             USA                 1988.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 5                    M                  M40                 7.792           5
# 11                   M                  NaN                 6.977          11
# 16                   M                  M45                 6.238          16
# 19                   M                  NaN                 6.082          19
# 20                   M                  NaN                 6.079          20
# ...                ...                  ...                   ...         ...
# 3609767              M                  NaN                 6.054     1044732
# 3609768              M                  NaN                 5.963     1044733
# 3609769              M                  M23                 5.927      935282
# 3609770              F                  NaN                 5.847      977490
# 3609771              M                  M23                 11.29      852361
#
# [1593013 rows x 13 columns]

# %%
#um_df = um_df.dropna()

# %%
#um_df.isnull().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete club                 0
# Athlete country              0
# Athlete year of birth        0
# Athlete gender               0
# Athlete age category         0
# Athlete average speed        0
# Athlete ID                   0
# dtype: int64

# %%
#um_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2016793 entries, 0 to 3609805
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 215.4+ MB

# %%
#um_df['Event dates'].unique()
# Out:
# array(['06.01.2018', '05.01.2018', '05.-06.01.2018', ...,
#        '21.-22.10.2022', '20.-23.10.2022', '16.-17.10.2022'],
#       shape=(2956,), dtype=object)

# %%
#um_df = um_df[um_df['Event dates'] >= '08-31-206']

# %%
#um_df['Event dates'].unique()
# Out:
# array(['24.03.2018', '24.-25.03.2018', '23.-25.03.2018', ...,
#        '21.-22.10.2022', '20.-23.10.2022', '16.-17.10.2022'],
#       shape=(2251,), dtype=object)

# %%
#um_df.tail()
# Out:
#          Year of event Event dates                          Event name  \
# 3609801           2022  16.10.2022  Tussey Mountainback 50 Miler (USA)
# 3609802           2022  16.10.2022  Tussey Mountainback 50 Miler (USA)
# 3609803           2022  16.10.2022  Tussey Mountainback 50 Miler (USA)
# 3609804           2022  16.10.2022  Tussey Mountainback 50 Miler (USA)
# 3609805           2022  16.10.2022  Tussey Mountainback 50 Miler (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 3609801                  50mi                         35          11:16:08 h
# 3609802                  50mi                         35          11:27:05 h
# 3609803                  50mi                         35          11:46:34 h
# 3609804                  50mi                         35          11:55:29 h
# 3609805                  50mi                         35          12:14:15 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 3609801  *Peachtree City, GA             USA                 1968.0
# 3609802         *Newport, PA             USA                 1959.0
# 3609803      *Flemington, NJ             USA                 1955.0
# 3609804       *Arlington, VA             USA                 1965.0
# 3609805       *Johnstown, PA             USA                 1981.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 3609801              M                  M50                 7.141     1044739
# 3609802              M                  M60                 7.027       50971
# 3609803              F                  W65                 6.833       73152
# 3609804              M                  M55                 6.748      970133
# 3609805              F                  W40                 6.575      723380

# %%
#months_in_um = um_df['Event dates'].tolist
#months_in_um
# Out:
# <bound method IndexOpsMixin.tolist of 665        24.03.2018
# 666        24.03.2018
# 667        24.03.2018
# 668        24.03.2018
# 669        24.03.2018
#               ...
# 3609801    16.10.2022
# 3609802    16.10.2022
# 3609803    16.10.2022
# 3609804    16.10.2022
# 3609805    16.10.2022
# Name: Event dates, Length: 1586627, dtype: object>

# %%
# convert to datetime

#um_df['Event dates'] = pd.to_datetime(um_df['Event dates'], format= '%d.%m.%Y', errors='coerce')

# %%
#um_df['Event dates'].dt.month.unique()
# Out:
# array([ 3., nan,  2.,  1.,  4.,  6.,  5.,  7.,  9.,  8., 10., 12., 11.])

# %%
#um_df['Event dates'].head(20)
# Out:
# 665   2018-03-24
# 666   2018-03-24
# 667   2018-03-24
# 668   2018-03-24
# 669   2018-03-24
# 670   2018-03-24
# 671   2018-03-24
# 674   2018-03-24
# 675   2018-03-24
# 676   2018-03-24
# 677   2018-03-24
# 678   2018-03-24
# 680   2018-03-24
# 681   2018-03-24
# 682   2018-03-24
# 683   2018-03-24
# 684   2018-03-24
# 687   2018-03-24
# 688   2018-03-24
# 689   2018-03-24
# Name: Event dates, dtype: datetime64[ns]

# %%
#um_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1586627 entries, 665 to 3609805
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Year of event              1586627 non-null  int64
#  1   Event dates                1237586 non-null  datetime64[ns]
#  2   Event name                 1586627 non-null  object
#  3   Event distance/length      1586627 non-null  object
#  4   Event number of finishers  1586627 non-null  int64
#  5   Athlete performance        1586627 non-null  object
#  6   Athlete club               1586627 non-null  object
#  7   Athlete country            1586627 non-null  object
#  8   Athlete year of birth      1586627 non-null  float64
#  9   Athlete gender             1586627 non-null  object
#  10  Athlete age category       1586627 non-null  object
#  11  Athlete average speed      1586627 non-null  object
#  12  Athlete ID                 1586627 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(8)
# memory usage: 169.5+ MB

# %%
#um_df = um_df[um_df['Event dates'].dt.month >= 9].reset_index(drop=True)

# %%
#um_df['Event dates'].dt.month.unique()
# Out:
# array([ 9, 10, 12, 11], dtype=int32)

# %%
#um_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341390 entries, 0 to 341389
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Year of event              341390 non-null  int64
#  1   Event dates                341390 non-null  datetime64[ns]
#  2   Event name                 341390 non-null  object
#  3   Event distance/length      341390 non-null  object
#  4   Event number of finishers  341390 non-null  int64
#  5   Athlete performance        341390 non-null  object
#  6   Athlete club               341390 non-null  object
#  7   Athlete country            341390 non-null  object
#  8   Athlete year of birth      341390 non-null  float64
#  9   Athlete gender             341390 non-null  object
#  10  Athlete age category       341390 non-null  object
#  11  Athlete average speed      341390 non-null  object
#  12  Athlete ID                 341390 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(8)
# memory usage: 33.9+ MB

# %%
#um_df.to_csv('Results_um.csv', index=False)

# %%
#um_df.tail()
# Out:
#         Year of event Event dates                          Event name  \
# 341385           2022  2022-10-16  Tussey Mountainback 50 Miler (USA)
# 341386           2022  2022-10-16  Tussey Mountainback 50 Miler (USA)
# 341387           2022  2022-10-16  Tussey Mountainback 50 Miler (USA)
# 341388           2022  2022-10-16  Tussey Mountainback 50 Miler (USA)
# 341389           2022  2022-10-16  Tussey Mountainback 50 Miler (USA)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 341385                  50mi                         35          11:16:08 h
# 341386                  50mi                         35          11:27:05 h
# 341387                  50mi                         35          11:46:34 h
# 341388                  50mi                         35          11:55:29 h
# 341389                  50mi                         35          12:14:15 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 341385  *Peachtree City, GA             USA                 1968.0
# 341386         *Newport, PA             USA                 1959.0
# 341387      *Flemington, NJ             USA                 1955.0
# 341388       *Arlington, VA             USA                 1965.0
# 341389       *Johnstown, PA             USA                 1981.0
#
#        Athlete gender Athlete age category Athlete average speed  Athlete ID
# 341385              M                  M50                 7.141     1044739
# 341386              M                  M60                 7.027       50971
# 341387              F                  W65                 6.833       73152
# 341388              M                  M55                 6.748      970133
# 341389              F                  W40                 6.575      723380

# %%
um_df = pd.read_csv("../Data/Results_um.csv")
um_df.head()
# Out:
#    Year of event Event dates  \
# 0           2018  2018-09-21
# 1           2018  2018-09-21
# 2           2018  2018-09-21
# 3           2018  2018-09-21
# 4           2018  2018-09-21
#
#                                          Event name Event distance/length  \
# 0  Peak District Challenge - Gold Ultra 100km (GBR)                 106km
# 1  Peak District Challenge - Gold Ultra 100km (GBR)                 106km
# 2  Peak District Challenge - Gold Ultra 100km (GBR)                 106km
# 3  Peak District Challenge - Gold Ultra 100km (GBR)                 106km
# 4  Peak District Challenge - Gold Ultra 100km (GBR)                 106km
#
#    Event number of finishers Athlete performance       Athlete club  \
# 0                         11          19:41:51 h            Team GG
# 1                         11          19:41:58 h            Team GG
# 2                         11          24:10:02 h  MAD Pat'S Brigade
# 3                         11          24:10:07 h  MAD Pat'S Brigade
# 4                         11          24:16:08 h  MAD Pat'S Brigade
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             RSA                 1985.0              M                  M23
# 1             GBR                 1986.0              M                  M23
# 2             GBR                 1972.0              M                  M45
# 3             GBR                 1959.0              F                  W55
# 4             GBR                 1962.0              M                  M55
#
#   Athlete average speed  Athlete ID
# 0                 5.381      266403
# 1                 5.381      266404
# 2                 4.386      266406
# 3                 4.386      266407
# 4                 4.368      266409
